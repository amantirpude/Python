# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\amant'

# %%
os.chdir('D:/Topmentor_Python_Class')

# %%
pwd
# Out:
# 'D:\\Topmentor_Python_Class'

# %%
df = pd.read_csv('D:/Topmentor_Python_Class/Telecom Retention_Telo company.csv')

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
telecom_data = df.copy()

# %%
telecom_data.head(n=4)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# ...

# %%
telecom_data.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
telecom_data.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
telecom_data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
telecom_data.shape
# Out:
# (2666, 20)

# %%
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
telecom_data['Churn'] = telecom_data['Churn'].astype('int64')

# %%
telecom_data
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
telecom_data.head(5)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
telecom_data.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
Customer_perdaycost = 100.310203 / 30.512404

# %%
Customer_perdaycost   ### Average Cost of Per Customer per day
# Out:
# 3.287522117234683

# %%
Customer_perevecost = 100.023631 / 17.033072

# %%
Customer_perevecost   ### Average Cost of Per Customer per Evening
# Out:
# 5.872318921683651

# %%
Customer_pernightcost = 100.106152 / 9.052689

# %%
Customer_pernightcost   ### Average Cost of Per Customer per Night
# Out:
# 11.058167578716112

# %%
telecom_data.describe(include = ['object', 'bool'])  ### describe only that data which is of object and boolean type
# Out:
#        State International plan Voice mail plan
# count   2666               2666            2666
# unique    51                  2               2
# top       WV                 No              No
# freq      88               2396            1933

# %%
telecom_data['Churn'].value_counts()  ### 2278 are the retained Customers and 388 are the churned customers
# Out:
# 0    2278
# 1     388
# Name: Churn, dtype: int64

# %%
telecom_data['Churn'].value_counts(normalize = True)*100 ### 85.44% are the Retained Customers and 14.55% are the Churned Customers
# Out:
# 0    85.446362
# 1    14.553638
# Name: Churn, dtype: float64

# %%
### Average of all the Neumrical Values only for Churned Customers
telecom_data[telecom_data['Churn']==1].mean()
# Out:
# Account length            102.319588
# Area code                 437.543814
# Number vmail messages       5.170103
# Total day minutes         205.181186
# Total day calls           101.195876
# Total day charge           34.881340
# Total eve minutes         209.385309
# Total eve calls            99.948454
# Total eve charge           17.797861
# Total night minutes       205.307216
# Total night calls         100.682990
# Total night charge          9.238892
# Total intl minutes         10.819330
# Total intl calls            4.051546
# Total intl charge           2.921727
# Customer service calls      2.206186
# Churn                       1.000000
# dtype: float64

# %%
### Average of all the Neumrical Values only for not Churned Customers
telecom_data[telecom_data['Churn']==0].mean()
# Out:
# Account length            100.330992
# Area code                 437.420983
# Number vmail messages       8.507463
# Total day minutes         175.104346
# Total day calls           100.159350
# Total day charge           29.768266
# Total eve minutes         198.853380
# Total eve calls           100.036435
# Total eve charge           16.902809
# Total night minutes       200.464091
# Total night calls         100.007902
# Total night charge          9.020975
# Total intl minutes         10.137840
# Total intl calls            4.538191
# Total intl charge           2.737709
# Customer service calls      1.453029
# Churn                       0.000000
# dtype: float64

# %%
### Time in Minutes user spend on a Day call for Churned Customers
telecom_data[telecom_data['Churn']==1]['Total day minutes'].mean()
# Out:
# 205.1811855670104

# %%
### Time in Minutes user spend on a Evening call for Churned Customers
telecom_data[telecom_data['Churn']==1]['Total eve minutes'].mean()
# Out:
# 209.38530927835052

# %%
### Time in Minutes user spend on a Night callfor Churned Customers
telecom_data[telecom_data['Churn']==1]['Total night minutes'].mean()
# Out:
# 205.30721649484514

# %%
### Time in Minutes user spend on a Day call for Retained Customers
telecom_data[telecom_data['Churn']==0]['Total day minutes'].mean()
# Out:
# 175.1043459174718

# %%
### Time in Minutes user spend on a Evening call for Retained Customers
telecom_data[telecom_data['Churn']==0]['Total eve minutes'].mean()
# Out:
# 198.85338015803347

# %%
### Time in Minutes user spend on a Night call for Retained Customers
telecom_data[telecom_data['Churn']==0]['Total night minutes'].mean()
# Out:
# 200.46409130816554

# %%
###Loyal Customers based on International Calls

# %%
telecom_data[telecom_data['Churn']==1]['Total intl calls'].mean()
# Out:
# 4.051546391752577

# %%
telecom_data[telecom_data['Churn']==0]['Total intl calls'].mean()
# Out:
# 4.53819139596137

# %%
### Those who are not having the International Plans are Churning Out
telecom_data[(telecom_data['Churn']==1) & (telecom_data['International plan'] == 'No')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 18      CO              77        408                 No              No
# 28      AZ              12        408                 No              No
# 45      WY              87        415                 No              No
# 48      CO             121        408                 No             Yes
# 58      TX             150        510                 No              No
# ...    ...             ...        ...                ...             ...
# 2614    ID              82        415                 No              No
# 2624    AR              76        408                 No              No
# 2628    KS             170        415                 No             Yes
# 2657    MD              62        408                 No              No
# 2658    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#### Inputing the Categorical values to Boolean values

# %%
f ={'No':False, 'Yes': True}

# %%
telecom_data['International plan'] = telecom_data['International plan'].map(f)

# %%
telecom_data
# Out:
#      State  Account length  Area code  International plan Voice mail plan  \
# 0       KS             128        415               False             Yes
# 1       OH             107        415               False             Yes
# 2       NJ             137        415               False              No
# 3       OH              84        408                True              No
# 4       OK              75        415                True              No
# ...    ...             ...        ...                 ...             ...
# 2661    SC              79        415               False              No
# 2662    AZ             192        415               False             Yes
# 2663    WV              68        415               False              No
# 2664    RI              28        510               False              No
# 2665    TN              74        415               False             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#### Replacing the categorical data with boolean values
telecom_data = telecom_data.replace({'Voice mail plan':f})

# %%
telecom_data
# Out:
#      State  Account length  Area code  International plan  Voice mail plan  \
# 0       KS             128        415               False             True
# 1       OH             107        415               False             True
# 2       NJ             137        415               False            False
# 3       OH              84        408                True            False
# 4       OK              75        415                True            False
# ...    ...             ...        ...                 ...              ...
# 2661    SC              79        415               False            False
# 2662    AZ             192        415               False             True
# 2663    WV              68        415               False            False
# 2664    RI              28        510               False            False
# 2665    TN              74        415               False             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   bool
#  4   Voice mail plan         2666 non-null   bool
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
### Describing the data by grouping it as Churn with Day Calls, Evening Calls and night Calls
col = ['Total day calls', 'Total eve calls', 'Total night calls']
telecom_data.groupby('Churn')[col].describe()
# Out:
#       Total day calls                                                         \
#                 count        mean        std  min   25%    50%    75%    max
# Churn
# 0              2278.0  100.159350  19.681914  0.0  87.0  100.0  113.0  160.0
# 1               388.0  101.195876  21.705279  0.0  87.0  103.0  116.0  156.0
#
#       Total eve calls              ...               Total night calls  \
#                 count        mean  ...    75%    max             count
# Churn                              ...
# 0              2278.0  100.036435  ...  114.0  170.0            2278.0
# 1               388.0   99.948454  ...  113.0  159.0             388.0
#
#
#              mean        std   min    25%    50%    75%    max
# Churn
# 0      100.007902  19.307282  33.0  87.00  100.0  113.0  166.0
# 1      100.682990  20.074667  49.0  85.75  101.0  116.0  158.0
#
# [2 rows x 24 columns]

# %%
### Describing the data by grouping it as Churn with Day Calls, Evening Calls and night Calls
col = ['Total day calls', 'Total eve calls', 'Total night calls']
telecom_data.groupby('Churn')[col].agg([np.mean, np.std, np.min, np.max])
# Out:
#       Total day calls                      Total eve calls                  \
#                  mean        std amin amax            mean        std amin
# Churn
# 0          100.159350  19.681914    0  160      100.036435  20.258800    0
# 1          101.195876  21.705279    0  156       99.948454  19.605474   48
#
#            Total night calls
#       amax              mean        std amin amax
# Churn
# 0      170        100.007902  19.307282   33  166
# 1      159        100.682990  20.074667   49  158

# %%
### Crosstab 2 columns
pd.crosstab(telecom_data['Churn'], telecom_data['International plan'])
# Out:
# International plan  False  True
# Churn
# 0                    2126    152
# 1                     270    118

# %%
pd.crosstab(telecom_data['Churn'], telecom_data['Voice mail plan'])
# Out:
# Voice mail plan  False  True
# Churn
# 0                 1610    668
# 1                  323     65

# %%
### Pivot table analysis
telecom_data.pivot_table(col,['State'], aggfunc = 'mean').sort_index(ascending = False)
# Out:
#        Total day calls  Total eve calls  Total night calls
# State
# WY          101.333333        99.166667         102.787879
# WV          104.500000        99.363636         100.715909
# WI           97.000000        99.081967          98.426230
# WA          100.520833        95.750000         103.750000
# VT          101.035088        96.982456         103.578947
# VA          105.910448       100.462687          93.104478
# UT           99.683333        97.866667         100.733333
# TX          101.236364       101.254545          99.290909
# TN           99.658537       105.853659          91.000000
# SD           93.918367        98.367347          94.081633
# SC          101.571429       100.714286          99.816327
# RI          100.875000        93.270833         101.750000
# PA           98.888889       100.361111          99.500000
# OR           94.564516        98.564516         102.209677
# OK           99.807692       105.057692         101.942308
# ...

# %%
### Grouping Coulums to find some insights
telecom_data.groupby(['Area code', 'State','Churn'])[col].mean()
# Out:
#                        Total day calls  Total eve calls  Total night calls
# Area code State Churn
# 408       AK    0            95.333333       103.555556         108.555556
#           AL    0            99.000000       102.444444         101.111111
#                 1           102.250000        86.250000          89.000000
#           AR    0           107.818182       109.454545          89.090909
#                 1           140.000000       133.000000         116.000000
# ...                                ...              ...                ...
# 510       WI    1            78.000000       108.000000          91.000000
#           WV    0           105.958333       102.583333          96.958333
#                 1            75.666667       120.333333          98.000000
#           WY    0           104.076923        99.692308         104.615385
#                 1           104.666667        96.666667          89.000000
#
# [285 rows x 3 columns]

# %%
Threshold = 0.7
abs(telecom_data.corr()['Churn']) > Threshold
# Out:
# Account length            False
# Area code                 False
# International plan        False
# Voice mail plan           False
# Number vmail messages     False
# Total day minutes         False
# Total day calls           False
# Total day charge          False
# Total eve minutes         False
# Total eve calls           False
# Total eve charge          False
# Total night minutes       False
# Total night calls         False
# Total night charge        False
# Total intl minutes        False
# Total intl calls          False
# Total intl charge         False
# Customer service calls    False
# Churn                      True
# Name: Churn, dtype: bool
